# %%
# Function to calculate the inside temperature for the next hour given current inside, outside temperature and power that the termostat is set to
# param T_in: Inside temperature based on last hour
# param T_out: Outside temperature based on forecast
# param k: Based on historical electricity use in business we solve for the constant
# param c_cool: We calculate a constant as conservation of total energy does not apply in this situation in this system
# param cm: Approximation for mass of air multiplied by heat capacity
# param V: Approximated volume of office building

# Power is now in kilowattitunti
# 


function T_c(T_in, T_out, power)
    Q_in = power # kWH
    k= 8/22 # [k] = kWh/K
    c_cool = 0.7264 #Dimensionless constant
    Q_out = k *(T_out - T_in) #The unit is kWh/K
    V = 12000 # m^3
    rho = 1.204 # kg/m^3
    c = 700/(3*10^6)
    cm = rho*c*V
    return (Q_in + Q_out)/cm*2.6 + T_in*c_cool

end

function P_bad(T_bad, T_out)
    tehohävio = (T_bad-T_out)*0.25*9.6
    return(10+tehohävio/2)
end
# Out:
# P_bad (generic function with 1 method)

# %%
using JuMP, Cbc
# Function to optimize heating of business building during a 24h period
# param o: Array of length 24, 1 if someone present else 0
# param p: Preference for saving energy over money
# param Ep: Hourly next day prize of electricity
# param T_opt: Optimal temperature
# param Pt: Acceptable deviation from optimal temperature
# param T_bad: Setting of the temperature for non-optimal model (assumed to be constant)
# param T_out_vec: Vector of forcasted outside temperatures for the comming day
# param T_end: Previous day last hour temperature
# param T_n_low: Lowest acceptable night temperature
# param T_n_hi: Highest acceptable night temperature
# param C: Constant denoting the proportion of people present and total working force at office

function Twenty_four(o, p, Ep, T_opt, Pt, T_bad, T_out_vec, T_end, T_n_low, T_n_hi, C,s1,s2)
    
    # Initialize vector for saving the hourly development of the temperature
    #Tc = Vector{Float64}(undef,25)
    #Tc[1] = T_end
   
    Tc_arr = zeros(24)
    Tc_arr[1] = T_end
    P_bad_arr = zeros(24)
    Optimal_vec = zeros(24)
    # Chained multi-parameter LP optimization
    for i in 1:24 
        Tc = Tc_arr[i]
        hourly_optimum = Model(with_optimizer(Cbc.Optimizer, logLevel = 0)) # Create the model for optimizing the hourly optimum thermostat setting
        
        @variable(hourly_optimum, power >= 0)

        P_bad_new = P_bad(T_bad,T_out_vec[i])
        Tc_new = T_c(Tc,T_out_vec[i],power)
        # Define constraints for money
        #@constraint(hourly_optimum,P_bad_new*Ep[i]-power*Ep[i] >= 0)
        
        # Define constraints for energy
        @constraint(hourly_optimum,Tc_new - (T_opt-(1-o[i])*(T_opt-T_n_low)) >= 0)
        @constraint(hourly_optimum,Tc_new - (T_opt+(1-o[i])*(T_n_hi-T_opt)) <= 0)
        
        #Objective function for optimization problem. We maximize a multiparameter problem for each hour, with terms energy saved, money saved and 
        @objective(hourly_optimum, Max, (1-p)*s1*(P_bad_new*Ep[i]-power*Ep[i]) + p*s2*(P_bad_new-power) - (T_opt - Tc_new)*C[i])
        
        optimize!(hourly_optimum);
        Optimal_vec[i] = value.(power)
        Tc_arr[i] = value.(Tc_new)
        P_bad_arr[i] = value.(P_bad_new)
    end
    return (Optimal_vec,Tc_arr,P_bad_arr)
end
# Out:
# Twenty_four (generic function with 1 method)

# %%
using CSV
using DataFrames 
using Statistics

# Read the data
C_df = DataFrame(CSV.File("/home/hannuls3/notebooks/Juction-2022-OTTER/Data/people_constant_factor.csv")) 
o_df = DataFrame(CSV.File("/notebooks/Juction-2022-OTTER/Data/people_flow_binary.csv")) 
E_df = DataFrame(CSV.File("/home/hannuls3/notebooks/Juction-2022-OTTER/Whole_year_electricity.csv",header =0)) 
o_df=o_df[:,2:365]
C_df=C_df[:,2:365]
T_out_vec = DataFrame(CSV.File("/home/hannuls3/notebooks/Juction-2022-OTTER/Data/penis.csv",header = 0))
# Out:
# 24×365 DataFrame
#  Row │ Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    9.05    10.01    10.01    10.02    11.09    11.02    12.05    11.04  ⋯
#    2 │    9.03    10.02    10.01    10.01    11.09    11.03    12.04    11.04
#    3 │    9.03    10.05    10.01     9.08    11.07    11.0     11.09    11.04
#    4 │    9.03    10.04     9.09     9.06    11.08    10.08    11.04    11.05
#    5 │    8.07    10.02     9.03     9.03    11.07    10.07    11.01    11.05  ⋯
#    6 │    8.05     9.09     9.04     9.03    11.06    11.0     11.0     11.05
#    7 │    8.08    10.0     10.0      9.09    11.06    10.08    10.07    11.06
#    8 │    8.08    10.06    10.07    10.03    11.04    10.09    11.05    11.07
#    9 │    9.04    11.03    11.02    10.08    10.08    11.06    11.05    11.06  ⋯
#   10 │    9.06    11.08    11.08    11.07    10.05    12.04    11.04    11.07
#   11 │   10.02    12.0     12.04    12.0     10.02    13.0     11.06    11.08
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮     ⋱
#   15 │   10.06    12.03    12.06    13.09    10.02    13.0     10.03    12.02
#   16 │   10.07    11.06    12.05    13.08     9.08    13.01    10.05    12.01  ⋯
#   17 │   10.07    11.01    12.03    13.08    10.0     12.08    10.07    11.08
#   18 │   10.07    11.06    11.09    12.06    10.05    13.02    11.0     11.09
#   19 │   10.08    11.09    11.07    12.05    10.05    13.03    11.01    11.08
#   20 │   10.03    11.04    11.05    12.09    10.09    13.0     11.03    11.06  ⋯
#   21 │   10.06    11.03    11.04    12.06    10.09    12.09    11.04    11.06
#   22 │   10.04    11.0     11.01    12.04    11.0     12.09    11.03    11.05
#   23 │   10.05    10.05    10.09    12.03    11.0     12.09    11.03    11.05
#   24 │   10.04    10.07    10.04    12.03    10.09    12.06    11.05    11.05  ⋯
#                                                   357 columns and 3 rows omitted

# %%
# For loop for extending the prediction to the whole year

preds = zeros(24,365)
temps = zeros(24,365)
base = zeros(24,365)

for i in 1:364
    tout = 19
    println(i)
    (preds[:,i], temps[:,i], base[:,i])= Twenty_four(o_df[:,i],0.5, E_df[:,i], 21.0, 2.0,21.0, T_out_vec[:,i], tout, 17.2, 25.0, C_df[:,i],100/0.0053,1000/0.29)
    tout = temps[24,i]
end



#CSV.write("/home/hannuls3/notebooks/Juction-2022-OTTER/Data/Optimized-data/ptimal_thermos.csv", DataFrame(preds, :auto))
#CSV.write("/home/hannuls3/notebooks/Juction-2022-OTTER/Data/Optimized-data/temp_data.csv", DataFrame(temps, :auto))
#CSV.write("/home/hannuls3/notebooks/Juction-2022-OTTER/Data/Optimized-data/base_data.csv", DataFrame(base, :auto))
# Out:
# 1
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -11055987
# After Postsolve, objective -11055987, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -11055987.3 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25997072
# After Postsolve, objective -25997072, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25997071.78 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25764396
# After Postsolve, objective -25764396, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25764396.08 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17579723
# After Postsolve, objective -17579723, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17579722.92 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17902411
# After Postsolve, objective -17902411, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17902410.56 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17532610
# After Postsolve, objective -17532610, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17532609.69 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17899049
# After Postsolve, objective -17899049, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17899049.23 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -22453526
# After Postsolve, objective -22453526, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -22453526.46 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -22130837
# After Postsolve, objective -22130837, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -22130837.03 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -15858271
# After Postsolve, objective -15858271, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -15858270.75 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17126634
# After Postsolve, objective -17126634, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17126633.52 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -18735781
# After Postsolve, objective -18735781, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -18735780.62 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -21101024
# After Postsolve, objective -21101024, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -21101024.06 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -21555622
# After Postsolve, objective -21555622, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -21555621.92 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -21787972
# After Postsolve, objective -21787972, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -21787972.4 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -21944686
# After Postsolve, objective -21944686, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -21944686.08 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25497541
# After Postsolve, objective -25497541, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25497541.45 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -33383628
# After Postsolve, objective -33383628, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -33383628.35 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -39436072
# After Postsolve, objective -39436072, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -39436071.81 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -41757928
# After Postsolve, objective -41757928, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -41757927.97 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -42125527
# After Postsolve, objective -42125527, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -42125526.6 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -42483298
# After Postsolve, objective -42483298, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -42483297.82 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -41938539
# After Postsolve, objective -41938539, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -41938539.35 - 0 iterations time 0.002, Presolve 0.00
# 2
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -37244977
# After Postsolve, objective -37244977, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -37244977.46 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -15859451
# After Postsolve, objective -15859451, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -15859451.42 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25822052
# After Postsolve, objective -25822052, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25822052.4 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -19474536
# After Postsolve, objective -19474536, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -19474536 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -19914694
# After Postsolve, objective -19914694, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -19914693.8 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -20427638
# After Postsolve, objective -20427638, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -20427637.5 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -19839115
# After Postsolve, objective -19839115, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -19839114.55 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -20435600
# After Postsolve, objective -20435600, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -20435599.96 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -28859206
# After Postsolve, objective -28859206, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -28859205.59 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25419947
# After Postsolve, objective -25419947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25419946.67 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25400037
# After Postsolve, objective -25400037, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25400036.77 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -24414671
# After Postsolve, objective -24414671, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -24414670.9 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -22747121
# After Postsolve, objective -22747121, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -22747121.29 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -22739995
# After Postsolve, objective -22739995, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -22739995.48 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -23868313
# After Postsolve, objective -23868313, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -23868312.78 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25021813
# After Postsolve, objective -25021813, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25021813.17 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -24013378
# After Postsolve, objective -24013378, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -24013377.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25427903
# After Postsolve, objective -25427903, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25427902.93 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35023622
# After Postsolve, objective -35023622, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35023622.11 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -42548111
# After Postsolve, objective -42548111, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -42548110.51 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -43402725
# After Postsolve, objective -43402725, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -43402724.64 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45683140
# After Postsolve, objective -45683140, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45683139.92 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45862387
# After Postsolve, objective -45862387, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45862386.59 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -42599069
# After Postsolve, objective -42599069, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -42599068.79 - 0 iterations time 0.002, Presolve 0.00
# 3
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -31333214
# After Postsolve, objective -31333214, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -31333213.58 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -13155732
# After Postsolve, objective -13155732, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -13155731.91 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35806819
# After Postsolve, objective -35806819, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35806818.53 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -27257254
# After Postsolve, objective -27257254, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -27257254.48 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -26889262
# After Postsolve, objective -26889262, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -26889261.96 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25956679
# After Postsolve, objective -25956679, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25956678.98 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -26735616
# After Postsolve, objective -26735616, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -26735616.09 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -27109368
# After Postsolve, objective -27109368, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -27109368.4 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35773700
# After Postsolve, objective -35773700, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35773699.81 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -41501637
# After Postsolve, objective -41501637, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -41501636.62 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -31670846
# After Postsolve, objective -31670846, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -31670846.18 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -27207143
# After Postsolve, objective -27207143, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -27207142.78 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -32833930
# After Postsolve, objective -32833930, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -32833929.83 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -31628528
# After Postsolve, objective -31628528, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -31628527.97 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -23575268
# After Postsolve, objective -23575268, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -23575267.82 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -21560910
# After Postsolve, objective -21560910, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -21560910.26 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -24367247
# After Postsolve, objective -24367247, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -24367246.74 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -27378414
# After Postsolve, objective -27378414, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -27378414.12 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -32534362
# After Postsolve, objective -32534362, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -32534361.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -38360753
# After Postsolve, objective -38360753, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -38360752.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -39454485
# After Postsolve, objective -39454485, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -39454484.71 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -26560103
# After Postsolve, objective -26560103, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -26560102.98 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -24533805
# After Postsolve, objective -24533805, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -24533804.78 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -20090396
# After Postsolve, objective -20090396, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -20090395.89 - 0 iterations time 0.002, Presolve 0.00
# 4
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17690665
# After Postsolve, objective -17690665, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17690664.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -14934910
# After Postsolve, objective -14934910, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -14934909.89 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25754822
# After Postsolve, objective -25754822, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25754821.59 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25613911
# After Postsolve, objective -25613911, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25613911.01 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -23932742
# After Postsolve, objective -23932742, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -23932742.45 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -18871522
# After Postsolve, objective -18871522, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -18871521.67 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -20685422
# After Postsolve, objective -20685422, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -20685422.41 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -27589976
# After Postsolve, objective -27589976, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -27589975.64 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35864744
# After Postsolve, objective -35864744, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35864744.2 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -39811760
# After Postsolve, objective -39811760, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -39811760.01 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -32790970
# After Postsolve, objective -32790970, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -32790970.47 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -32163905
# After Postsolve, objective -32163905, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -32163905.11 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -39351701
# After Postsolve, objective -39351701, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -39351701.04 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -38125994
# After Postsolve, objective -38125994, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -38125994.06 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -29756497
# After Postsolve, objective -29756497, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -29756497.46 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -27037973
# After Postsolve, objective -27037973, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -27037973.22 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -33387175
# After Postsolve, objective -33387175, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -33387175.23 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -33387176
# After Postsolve, objective -33387176, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -33387175.7 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35334699
# After Postsolve, objective -35334699, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35334698.55 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -39901123
# After Postsolve, objective -39901123, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -39901123.15 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -38594082
# After Postsolve, objective -38594082, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -38594081.62 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -26418602
# After Postsolve, objective -26418602, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -26418602.02 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -25166219
# After Postsolve, objective -25166219, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -25166219.33 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -23356615
# After Postsolve, objective -23356615, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -23356614.93 - 0 iterations time 0.002, Presolve 0.00
# 5
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -17789023
# After Postsolve, objective -17789023, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -17789023.3 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -13856273
# After Postsolve, objective -13856273, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -13856272.9 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -18145441
# After Postsolve, objective -18145441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -18145441.08 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -14600850
# After Postsolve, objective -14600850, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -14600849.51 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -13025803
# After Postsolve, objective -13025803, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -13025803.24 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -13671515
# After Postsolve, objective -13671515, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -13671515.37 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -20792856
# After Postsolve, objective -20792856, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -20792856.24 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -37048776
# After Postsolve, objective -37048776, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -37048776.32 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45170088
# After Postsolve, objective -45170088, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45170088.13 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46974163
# After Postsolve, objective -46974163, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46974162.9 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47603055
# After Postsolve, objective -47603055, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47603054.8 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46565967
# After Postsolve, objective -46565967, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46565967.38 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45171162
# After Postsolve, objective -45171162, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45171162.45 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -44530447
# After Postsolve, objective -44530447, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -44530447.24 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -43949334
# After Postsolve, objective -43949334, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -43949334.49 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -43562182
# After Postsolve, objective -43562182, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -43562181.95 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45186722
# After Postsolve, objective -45186722, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45186722.49 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45905936
# After Postsolve, objective -45905936, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45905935.81 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47018144
# After Postsolve, objective -47018144, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47018143.75 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50080588
# After Postsolve, objective -50080588, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50080588.05 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -55681821
# After Postsolve, objective -55681821, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -55681821.17 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -53812596
# After Postsolve, objective -53812596, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -53812596.31 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -48020921
# After Postsolve, objective -48020921, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -48020920.59 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45502996
# After Postsolve, objective -45502996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45502995.8 - 0 iterations time 0.002, Presolve 0.00
# 6
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -44493134
# After Postsolve, objective -44493134, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -44493133.63 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -14294686
# After Postsolve, objective -14294686, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -14294685.95 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -44771944
# After Postsolve, objective -44771944, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -44771944.03 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -33150879
# After Postsolve, objective -33150879, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -33150878.62 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -31801800
# After Postsolve, objective -31801800, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -31801799.94 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -29944009
# After Postsolve, objective -29944009, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -29944008.54 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -33592884
# After Postsolve, objective -33592884, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -33592883.99 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35936955
# After Postsolve, objective -35936955, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35936955.44 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -48080451
# After Postsolve, objective -48080451, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -48080450.69 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -48078716
# After Postsolve, objective -48078716, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -48078715.61 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47465456
# After Postsolve, objective -47465456, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47465456.02 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45657696
# After Postsolve, objective -45657696, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45657696.3 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -44821323
# After Postsolve, objective -44821323, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -44821322.63 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -44210746
# After Postsolve, objective -44210746, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -44210746.17 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -43414066
# After Postsolve, objective -43414066, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -43414066.43 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -41823925
# After Postsolve, objective -41823925, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -41823924.55 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -40342059
# After Postsolve, objective -40342059, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -40342058.77 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -43594021
# After Postsolve, objective -43594021, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -43594020.93 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47215426
# After Postsolve, objective -47215426, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47215426 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -58056393
# After Postsolve, objective -58056393, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -58056393.14 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -59128970
# After Postsolve, objective -59128970, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -59128969.88 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -54258071
# After Postsolve, objective -54258071, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -54258071 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -49573090
# After Postsolve, objective -49573090, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -49573090.29 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46660865
# After Postsolve, objective -46660865, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46660865.19 - 0 iterations time 0.002, Presolve 0.00
# 7
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45295312
# After Postsolve, objective -45295312, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45295312.18 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -23906593
# After Postsolve, objective -23906593, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -23906592.56 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -40782700
# After Postsolve, objective -40782700, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -40782700.35 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -31054426
# After Postsolve, objective -31054426, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -31054425.94 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -28480263
# After Postsolve, objective -28480263, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -28480263.1 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -28134742
# After Postsolve, objective -28134742, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -28134742.26 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -28520182
# After Postsolve, objective -28520182, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -28520181.8 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -29082350
# After Postsolve, objective -29082350, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -29082349.71 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47313291
# After Postsolve, objective -47313291, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47313290.67 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -53433480
# After Postsolve, objective -53433480, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -53433480.06 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -54793098
# After Postsolve, objective -54793098, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -54793097.8 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -52584387
# After Postsolve, objective -52584387, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -52584387.44 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50980878
# After Postsolve, objective -50980878, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50980877.54 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -48133830
# After Postsolve, objective -48133830, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -48133830.08 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47197876
# After Postsolve, objective -47197876, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47197875.65 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46102730
# After Postsolve, objective -46102730, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46102730.31 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46769054
# After Postsolve, objective -46769054, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46769053.92 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -49000166
# After Postsolve, objective -49000166, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -49000166.28 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -53475327
# After Postsolve, objective -53475327, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -53475326.96 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -57007718
# After Postsolve, objective -57007718, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -57007717.73 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -54799490
# After Postsolve, objective -54799490, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -54799490.07 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -53441846
# After Postsolve, objective -53441846, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -53441845.62 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -53450221
# After Postsolve, objective -53450221, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -53450220.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -51665065
# After Postsolve, objective -51665065, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -51665065.25 - 0 iterations time 0.002, Presolve 0.00
# 8
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47140305
# After Postsolve, objective -47140305, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47140305.44 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -18610758
# After Postsolve, objective -18610758, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -18610758.41 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -52132212
# After Postsolve, objective -52132212, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -52132211.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47320704
# After Postsolve, objective -47320704, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47320703.8 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -36502136
# After Postsolve, objective -36502136, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -36502136.43 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -34684125
# After Postsolve, objective -34684125, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -34684125.36 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -34528887
# After Postsolve, objective -34528887, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -34528887.22 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -34756555
# After Postsolve, objective -34756555, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -34756555.31 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45809942
# After Postsolve, objective -45809942, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45809941.77 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47305877
# After Postsolve, objective -47305877, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47305877.36 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50606048
# After Postsolve, objective -50606048, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50606048.36 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50149436
# After Postsolve, objective -50149436, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50149436.05 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47189001
# After Postsolve, objective -47189001, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47189001.43 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -44622408
# After Postsolve, objective -44622408, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -44622407.88 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -39939455
# After Postsolve, objective -39939455, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -39939454.96 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -36594968
# After Postsolve, objective -36594968, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -36594968.17 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35151449
# After Postsolve, objective -35151449, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35151449.13 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -35437241
# After Postsolve, objective -35437241, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -35437241.37 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -41596187
# After Postsolve, objective -41596187, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -41596186.81 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45275288
# After Postsolve, objective -45275288, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45275287.95 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46016347
# After Postsolve, objective -46016347, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46016347.49 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -46016348
# After Postsolve, objective -46016348, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -46016347.78 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -45885608
# After Postsolve, objective -45885608, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -45885607.83 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -40615020
# After Postsolve, objective -40615020, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -40615019.55 - 0 iterations time 0.002, Presolve 0.00
# 9
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -32434330
# After Postsolve, objective -32434330, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -32434329.55 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -12612276
# After Postsolve, objective -12612276, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -12612275.8 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -19661853
# After Postsolve, objective -19661853, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -19661853.36 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -13871866
# After Postsolve, objective -13871866, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -13871865.8 - 0 iterations time 0.002, Presolve 0.00
# ...
# Optimal objective -55190195.92 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -65240857
# After Postsolve, objective -65240857, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -65240856.56 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -64888565
# After Postsolve, objective -64888565, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -64888565.27 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -64518031
# After Postsolve, objective -64518031, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -64518031.33 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -60807259
# After Postsolve, objective -60807259, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -60807258.59 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -57661520
# After Postsolve, objective -57661520, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -57661519.92 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -55257914
# After Postsolve, objective -55257914, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -55257914.23 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50137191
# After Postsolve, objective -50137191, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50137190.84 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -52114196
# After Postsolve, objective -52114196, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -52114196.01 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -49899794
# After Postsolve, objective -49899794, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -49899794.44 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -49631707
# After Postsolve, objective -49631707, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -49631706.83 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -55446194
# After Postsolve, objective -55446194, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -55446193.78 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -62375947
# After Postsolve, objective -62375947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -62375947.47 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -73721275
# After Postsolve, objective -73721275, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -73721274.72 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -80496415
# After Postsolve, objective -80496415, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -80496414.7 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -77990992
# After Postsolve, objective -77990992, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -77990992.47 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -75588702
# After Postsolve, objective -75588702, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -75588702.48 - 0 iterations time 0.002, Presolve 0.00
# 87
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -59065281
# After Postsolve, objective -59065281, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -59065280.81 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -31423944
# After Postsolve, objective -31423944, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -31423944.11 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -61879574
# After Postsolve, objective -61879574, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -61879573.59 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -51276635
# After Postsolve, objective -51276635, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -51276634.6 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50767695
# After Postsolve, objective -50767695, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50767695.27 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -50910763
# After Postsolve, objective -50910763, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -50910763.02 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -55732061
# After Postsolve, objective -55732061, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -55732061.5 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -63988955
# After Postsolve, objective -63988955, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -63988954.9 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -75645947
# After Postsolve, objective -75645947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -75645946.75 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -76160026
# After Postsolve, objective -76160026, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -76160025.63 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -65320469
# After Postsolve, objective -65320469, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -65320468.72 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -63247190
# After Postsolve, objective -63247190, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -63247190.04 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -73062893
# After Postsolve, objective -73062893, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -73062893.22 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -71746052
# After Postsolve, objective -71746052, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -71746051.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -55502239
# After Postsolve, objective -55502239, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -55502239.23 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -54529968
# After Postsolve, objective -54529968, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -54529968.36 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -62601168
# After Postsolve, objective -62601168, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -62601167.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -62426159
# After Postsolve, objective -62426159, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -62426159.46 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -61346427
# After Postsolve, objective -61346427, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -61346426.87 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -72586854
# After Postsolve, objective -72586854, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -72586854.13 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -76843309
# After Postsolve, objective -76843309, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -76843309.43 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -73306705
# After Postsolve, objective -73306705, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -73306704.85 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -71626205
# After Postsolve, objective -71626205, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -71626204.64 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -65616140
# After Postsolve, objective -65616140, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -65616140.37 - 0 iterations time 0.002, Presolve 0.00
# 88
# Excessive output truncated after 526437 bytes.
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -62256782
# After Postsolve, objective -62256782, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -62256782.2 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -47484170
# After Postsolve, objective -47484170, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -47484169.61 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -64680036
# After Postsolve, objective -64680036, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -64680036.21 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -62627703
# After Postsolve, objective -62627703, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -62627703.27 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -62499295
# After Postsolve, objective -62499295, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -62499294.93 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -54185468
# After Postsolve, objective -54185468, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -54185468.02 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -56988266
# After Postsolve, objective -56988266, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -56988266.16 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -65581111
# After Postsolve, objective -65581111, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -65581111.01 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -78318272
# After Postsolve, objective -78318272, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -78318272.38 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -82363638
# After Postsolve, objective -82363638, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -82363638.34 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -70190351
# After Postsolve, objective -70190351, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -70190350.98 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -67620294
# After Postsolve, objective -67620294, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -67620293.65 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -80317056
# After Postsolve, objective -80317056, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -80317056.03 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -79936959
# After Postsolve, objective -79936959, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -79936958.57 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -63388846
# After Postsolve, objective -63388846, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -63388845.93 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -61498937
# After Postsolve, objective -61498937, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -61498936.69 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -71832844
# After Postsolve, objective -71832844, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -71832843.51 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -71121830
# After Postsolve, objective -71121830, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -71121830.07 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -74038827
# After Postsolve, objective -74038827, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -74038826.71 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -74753279
# After Postsolve, objective -74753279, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -74753278.58 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -76152826
# After Postsolve, objective -76152826, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -76152825.72 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -68515338
# After Postsolve, objective -68515338, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -68515338.34 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -69575450
# After Postsolve, objective -69575450, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -69575450.38 - 0 iterations time 0.002, Presolve 0.00
# Presolve 0 (-2) rows, 0 (-1) columns and 0 (-2) elements
# Optimal - objective value -66194757
# After Postsolve, objective -66194757, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -66194757.01 - 0 iterations time 0.002, Presolve 0.00
# 89
# "/home/hannuls3/notebooks/Juction-2022-OTTER/Data/Optimized-data/base_data.csv"
